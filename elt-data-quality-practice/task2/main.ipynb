# %%
import pandas as pd

from task2.services.converters.converter import convert_to_employees
from task2.services.db.data_inserter import insert_data
from task2.services.generators.department_generator import generate_departments
from task2.services.transformations.base_transformations import trim_all_values
from task2.utls.logger_config import logger
from task2.models.base import Base, engine
from task2.services.schema.schema_definitions import EMPLOYEE_SCHEMA

# Create all tables in the database
Base.metadata.create_all(engine)
print("Database tables created successfully!")
# Out:
# 2025-04-13 17:49:45,840 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 17:49:45 INFO: BEGIN (implicit)
# 2025-04-13 17:49:45,841 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("departments")
# 17:49:45 INFO: PRAGMA main.table_info("departments")
# 2025-04-13 17:49:45,841 INFO sqlalchemy.engine.Engine [raw sql] ()
# 17:49:45 INFO: [raw sql] ()
# 2025-04-13 17:49:45,842 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("departments")
# 17:49:45 INFO: PRAGMA temp.table_info("departments")
# 2025-04-13 17:49:45,843 INFO sqlalchemy.engine.Engine [raw sql] ()
# 17:49:45 INFO: [raw sql] ()
# 2025-04-13 17:49:45,843 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("employees")
# 17:49:45 INFO: PRAGMA main.table_info("employees")
# 2025-04-13 17:49:45,844 INFO sqlalchemy.engine.Engine [raw sql] ()
# 17:49:45 INFO: [raw sql] ()
# 2025-04-13 17:49:45,844 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("employees")
# 17:49:45 INFO: PRAGMA temp.table_info("employees")
# 2025-04-13 17:49:45,845 INFO sqlalchemy.engine.Engine [raw sql] ()
# 17:49:45 INFO: [raw sql] ()
# 2025-04-13 17:49:45,845 INFO sqlalchemy.engine.Engine
# CREATE TABLE departments (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(30) NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 17:49:45 INFO:
# CREATE TABLE departments (
# 	id INTEGER NOT NULL,
# 	name VARCHAR(30) NOT NULL,
# 	PRIMARY KEY (id)
# )
#
#
# 2025-04-13 17:49:45,846 INFO sqlalchemy.engine.Engine [no key 0.00044s] ()
# 17:49:45 INFO: [no key 0.00044s] ()
# 2025-04-13 17:49:45,847 INFO sqlalchemy.engine.Engine
# CREATE TABLE employees (
# 	id INTEGER NOT NULL,
# 	name TEXT NOT NULL,
# 	date_of_birth DATE NOT NULL,
# 	salary INTEGER NOT NULL,
# 	department_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(department_id) REFERENCES departments (id)
# )
#
#
# 17:49:45 INFO:
# CREATE TABLE employees (
# 	id INTEGER NOT NULL,
# 	name TEXT NOT NULL,
# 	date_of_birth DATE NOT NULL,
# 	salary INTEGER NOT NULL,
# 	department_id INTEGER NOT NULL,
# 	PRIMARY KEY (id),
# 	FOREIGN KEY(department_id) REFERENCES departments (id)
# )
#
#
# 2025-04-13 17:49:45,848 INFO sqlalchemy.engine.Engine [no key 0.00046s] ()
# 17:49:45 INFO: [no key 0.00046s] ()
# 2025-04-13 17:49:45,848 INFO sqlalchemy.engine.Engine COMMIT
# 17:49:45 INFO: COMMIT
# Database tables created successfully!

# %%
logger.info("Starting transformation: first trim, then convert types\n")
emp_df:pd.DataFrame =  pd.read_csv("./data/employees.csv", delimiter=',', header=0)

# Apply the transformation: trim values
transformed_emp_df = trim_all_values(emp_df, EMPLOYEE_SCHEMA)
print(transformed_emp_df.head(1))
# Out:
# 17:49:45 INFO: Starting transformation: first trim, then convert types
#
# trim_all_values executed in 0.0011 seconds
#                                      id       name date_of_birth  salary  \
# 0  1dd3b13a-0b76-4468-b7c0-39ef57828315  James Lee    1973-09-15  145198
#
#   department_id
# 0             8

# %%
# Convert DataFrame to Employees ORM instances
employee_instances = convert_to_employees(transformed_emp_df)

# Use the inserter to insert employee data into the database
insert_data(engine, employee_instances)
# Out:
# 2025-04-13 17:49:46,110 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 17:49:46 INFO: BEGIN (implicit)
# 2025-04-13 17:49:46,113 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,113 INFO sqlalchemy.engine.Engine [generated in 0.00023s (insertmanyvalues) 1/100 (ordered; batch not supported)] ('James Lee', '1973-09-15', '145198', '8')
# 17:49:46 INFO: [generated in 0.00023s (insertmanyvalues) 1/100 (ordered; batch not supported)] ('James Lee', '1973-09-15', '145198', '8')
# 2025-04-13 17:49:46,114 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,115 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/100 (ordered; batch not supported)] ('Dustin Jackson', '1976-08-02', '70001', '6')
# 17:49:46 INFO: [insertmanyvalues 2/100 (ordered; batch not supported)] ('Dustin Jackson', '1976-08-02', '70001', '6')
# 2025-04-13 17:49:46,115 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,115 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/100 (ordered; batch not supported)] ('David Clark', '1979-04-17', '107474', '5')
# 17:49:46 INFO: [insertmanyvalues 3/100 (ordered; batch not supported)] ('David Clark', '1979-04-17', '107474', '5')
# 2025-04-13 17:49:46,116 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,116 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/100 (ordered; batch not supported)] ('Jose West', '1991-12-10', '68319', '7')
# 17:49:46 INFO: [insertmanyvalues 4/100 (ordered; batch not supported)] ('Jose West', '1991-12-10', '68319', '7')
# 2025-04-13 17:49:46,117 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,117 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/100 (ordered; batch not supported)] ('Stephanie Johnson', '1971-11-13', '123717', '5')
# 17:49:46 INFO: [insertmanyvalues 5/100 (ordered; batch not supported)] ('Stephanie Johnson', '1971-11-13', '123717', '5')
# 2025-04-13 17:49:46,118 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,118 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/100 (ordered; batch not supported)] ('Aaron Delacruz', '2006-05-08', '42778', '1')
# 17:49:46 INFO: [insertmanyvalues 6/100 (ordered; batch not supported)] ('Aaron Delacruz', '2006-05-08', '42778', '1')
# 2025-04-13 17:49:46,118 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,119 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/100 (ordered; batch not supported)] ('Jose Shaw', '2003-07-21', '82966', '7')
# 17:49:46 INFO: [insertmanyvalues 7/100 (ordered; batch not supported)] ('Jose Shaw', '2003-07-21', '82966', '7')
# 2025-04-13 17:49:46,119 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,119 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/100 (ordered; batch not supported)] ('Victoria Heath', '1973-06-19', '93087', '8')
# 17:49:46 INFO: [insertmanyvalues 8/100 (ordered; batch not supported)] ('Victoria Heath', '1973-06-19', '93087', '8')
# 2025-04-13 17:49:46,120 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,120 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/100 (ordered; batch not supported)] ('Brenda Richards', '2003-09-16', '115176', '4')
# 17:49:46 INFO: [insertmanyvalues 9/100 (ordered; batch not supported)] ('Brenda Richards', '2003-09-16', '115176', '4')
# 2025-04-13 17:49:46,121 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,121 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/100 (ordered; batch not supported)] ('Audrey Sanchez', '1989-09-11', '99604', '10')
# 17:49:46 INFO: [insertmanyvalues 10/100 (ordered; batch not supported)] ('Audrey Sanchez', '1989-09-11', '99604', '10')
# 2025-04-13 17:49:46,122 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,122 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/100 (ordered; batch not supported)] ('Debra Archer', '1971-02-23', '142070', '6')
# 17:49:46 INFO: [insertmanyvalues 11/100 (ordered; batch not supported)] ('Debra Archer', '1971-02-23', '142070', '6')
# 2025-04-13 17:49:46,122 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,122 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/100 (ordered; batch not supported)] ('Sean Patton', '1993-07-23', '100368', '5')
# 17:49:46 INFO: [insertmanyvalues 12/100 (ordered; batch not supported)] ('Sean Patton', '1993-07-23', '100368', '5')
# 2025-04-13 17:49:46,123 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,123 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/100 (ordered; batch not supported)] ('William Gilmore', '1992-06-14', '54327', '5')
# 17:49:46 INFO: [insertmanyvalues 13/100 (ordered; batch not supported)] ('William Gilmore', '1992-06-14', '54327', '5')
# 2025-04-13 17:49:46,124 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,124 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/100 (ordered; batch not supported)] ('Jessica Brooks', '1972-06-17', '62105', '3')
# 17:49:46 INFO: [insertmanyvalues 14/100 (ordered; batch not supported)] ('Jessica Brooks', '1972-06-17', '62105', '3')
# 2025-04-13 17:49:46,124 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,125 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/100 (ordered; batch not supported)] ('Peter Moran', '1990-03-10', '145720', '5')
# 17:49:46 INFO: [insertmanyvalues 15/100 (ordered; batch not supported)] ('Peter Moran', '1990-03-10', '145720', '5')
# 2025-04-13 17:49:46,125 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,126 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/100 (ordered; batch not supported)] ('Pamela Kirby', '1982-11-17', '67851', '9')
# 17:49:46 INFO: [insertmanyvalues 16/100 (ordered; batch not supported)] ('Pamela Kirby', '1982-11-17', '67851', '9')
# 2025-04-13 17:49:46,126 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,126 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/100 (ordered; batch not supported)] ('Peggy Sanchez', '1982-07-23', '42496', '8')
# 17:49:46 INFO: [insertmanyvalues 17/100 (ordered; batch not supported)] ('Peggy Sanchez', '1982-07-23', '42496', '8')
# 2025-04-13 17:49:46,127 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,127 INFO sqlalchemy.engine.Engine [insertmanyvalues 18/100 (ordered; batch not supported)] ('Brenda Crane', '1997-08-16', '93003', '7')
# 17:49:46 INFO: [insertmanyvalues 18/100 (ordered; batch not supported)] ('Brenda Crane', '1997-08-16', '93003', '7')
# 2025-04-13 17:49:46,127 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,128 INFO sqlalchemy.engine.Engine [insertmanyvalues 19/100 (ordered; batch not supported)] ('Terri Henry', '1996-01-02', '125372', '7')
# 17:49:46 INFO: [insertmanyvalues 19/100 (ordered; batch not supported)] ('Terri Henry', '1996-01-02', '125372', '7')
# 2025-04-13 17:49:46,128 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,129 INFO sqlalchemy.engine.Engine [insertmanyvalues 20/100 (ordered; batch not supported)] ('Caroline Patton', '1988-07-13', '52662', '4')
# 17:49:46 INFO: [insertmanyvalues 20/100 (ordered; batch not supported)] ('Caroline Patton', '1988-07-13', '52662', '4')
# 2025-04-13 17:49:46,129 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,129 INFO sqlalchemy.engine.Engine [insertmanyvalues 21/100 (ordered; batch not supported)] ('Tiffany Bailey', '1981-01-06', '149594', '4')
# 17:49:46 INFO: [insertmanyvalues 21/100 (ordered; batch not supported)] ('Tiffany Bailey', '1981-01-06', '149594', '4')
# 2025-04-13 17:49:46,130 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,130 INFO sqlalchemy.engine.Engine [insertmanyvalues 22/100 (ordered; batch not supported)] ('Tammy Rose', '1983-10-17', '67229', '9')
# 17:49:46 INFO: [insertmanyvalues 22/100 (ordered; batch not supported)] ('Tammy Rose', '1983-10-17', '67229', '9')
# 2025-04-13 17:49:46,130 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,131 INFO sqlalchemy.engine.Engine [insertmanyvalues 23/100 (ordered; batch not supported)] ('Heidi Perry', '2003-02-24', '119138', '4')
# 17:49:46 INFO: [insertmanyvalues 23/100 (ordered; batch not supported)] ('Heidi Perry', '2003-02-24', '119138', '4')
# 2025-04-13 17:49:46,131 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,131 INFO sqlalchemy.engine.Engine [insertmanyvalues 24/100 (ordered; batch not supported)] ('Michael Martin', '1993-07-27', '48230', '2')
# 17:49:46 INFO: [insertmanyvalues 24/100 (ordered; batch not supported)] ('Michael Martin', '1993-07-27', '48230', '2')
# 2025-04-13 17:49:46,132 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,132 INFO sqlalchemy.engine.Engine [insertmanyvalues 25/100 (ordered; batch not supported)] ('Joseph Russell', '1993-08-29', '135316', '5')
# 17:49:46 INFO: [insertmanyvalues 25/100 (ordered; batch not supported)] ('Joseph Russell', '1993-08-29', '135316', '5')
# 2025-04-13 17:49:46,132 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,133 INFO sqlalchemy.engine.Engine [insertmanyvalues 26/100 (ordered; batch not supported)] ('Thomas Stark', '1982-12-30', '103364', '9')
# 17:49:46 INFO: [insertmanyvalues 26/100 (ordered; batch not supported)] ('Thomas Stark', '1982-12-30', '103364', '9')
# 2025-04-13 17:49:46,133 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,134 INFO sqlalchemy.engine.Engine [insertmanyvalues 27/100 (ordered; batch not supported)] ('Earl Brooks', '1970-02-18', '47080', '9')
# 17:49:46 INFO: [insertmanyvalues 27/100 (ordered; batch not supported)] ('Earl Brooks', '1970-02-18', '47080', '9')
# 2025-04-13 17:49:46,134 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,135 INFO sqlalchemy.engine.Engine [insertmanyvalues 28/100 (ordered; batch not supported)] ('Kimberly Barnes', '1984-11-06', '98821', '4')
# 17:49:46 INFO: [insertmanyvalues 28/100 (ordered; batch not supported)] ('Kimberly Barnes', '1984-11-06', '98821', '4')
# 2025-04-13 17:49:46,135 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,135 INFO sqlalchemy.engine.Engine [insertmanyvalues 29/100 (ordered; batch not supported)] ('Alexis White', '1993-10-10', '75393', '9')
# 17:49:46 INFO: [insertmanyvalues 29/100 (ordered; batch not supported)] ('Alexis White', '1993-10-10', '75393', '9')
# 2025-04-13 17:49:46,136 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,136 INFO sqlalchemy.engine.Engine [insertmanyvalues 30/100 (ordered; batch not supported)] ('Joseph Davis', '1997-02-02', '96415', '1')
# 17:49:46 INFO: [insertmanyvalues 30/100 (ordered; batch not supported)] ('Joseph Davis', '1997-02-02', '96415', '1')
# 2025-04-13 17:49:46,137 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,137 INFO sqlalchemy.engine.Engine [insertmanyvalues 31/100 (ordered; batch not supported)] ('Raymond Cobb', '1969-11-07', '30381', '10')
# 17:49:46 INFO: [insertmanyvalues 31/100 (ordered; batch not supported)] ('Raymond Cobb', '1969-11-07', '30381', '10')
# 2025-04-13 17:49:46,137 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,138 INFO sqlalchemy.engine.Engine [insertmanyvalues 32/100 (ordered; batch not supported)] ('Alexander Alexander', '1991-05-14', '118105', '1')
# 17:49:46 INFO: [insertmanyvalues 32/100 (ordered; batch not supported)] ('Alexander Alexander', '1991-05-14', '118105', '1')
# 2025-04-13 17:49:46,138 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,138 INFO sqlalchemy.engine.Engine [insertmanyvalues 33/100 (ordered; batch not supported)] ('Ryan Lucero', '2006-03-22', '112481', '1')
# 17:49:46 INFO: [insertmanyvalues 33/100 (ordered; batch not supported)] ('Ryan Lucero', '2006-03-22', '112481', '1')
# 2025-04-13 17:49:46,139 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,139 INFO sqlalchemy.engine.Engine [insertmanyvalues 34/100 (ordered; batch not supported)] ('Jeffery Freeman', '1977-11-09', '96868', '7')
# 17:49:46 INFO: [insertmanyvalues 34/100 (ordered; batch not supported)] ('Jeffery Freeman', '1977-11-09', '96868', '7')
# 2025-04-13 17:49:46,139 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,140 INFO sqlalchemy.engine.Engine [insertmanyvalues 35/100 (ordered; batch not supported)] ('Robert Smith', '1974-04-03', '140168', '8')
# 17:49:46 INFO: [insertmanyvalues 35/100 (ordered; batch not supported)] ('Robert Smith', '1974-04-03', '140168', '8')
# 2025-04-13 17:49:46,140 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,140 INFO sqlalchemy.engine.Engine [insertmanyvalues 36/100 (ordered; batch not supported)] ('Kelly Dickerson', '1985-07-25', '107656', '4')
# 17:49:46 INFO: [insertmanyvalues 36/100 (ordered; batch not supported)] ('Kelly Dickerson', '1985-07-25', '107656', '4')
# 2025-04-13 17:49:46,141 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,141 INFO sqlalchemy.engine.Engine [insertmanyvalues 37/100 (ordered; batch not supported)] ('Richard Lowery', '1986-05-07', '100756', '6')
# 17:49:46 INFO: [insertmanyvalues 37/100 (ordered; batch not supported)] ('Richard Lowery', '1986-05-07', '100756', '6')
# 2025-04-13 17:49:46,141 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,142 INFO sqlalchemy.engine.Engine [insertmanyvalues 38/100 (ordered; batch not supported)] ('Monica Snow', '1991-05-13', '41831', '10')
# 17:49:46 INFO: [insertmanyvalues 38/100 (ordered; batch not supported)] ('Monica Snow', '1991-05-13', '41831', '10')
# 2025-04-13 17:49:46,142 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,143 INFO sqlalchemy.engine.Engine [insertmanyvalues 39/100 (ordered; batch not supported)] ('Paul Kirk', '1979-02-14', '77071', '3')
# 17:49:46 INFO: [insertmanyvalues 39/100 (ordered; batch not supported)] ('Paul Kirk', '1979-02-14', '77071', '3')
# 2025-04-13 17:49:46,143 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,143 INFO sqlalchemy.engine.Engine [insertmanyvalues 40/100 (ordered; batch not supported)] ('Bradley Campbell', '2002-09-21', '93774', '9')
# 17:49:46 INFO: [insertmanyvalues 40/100 (ordered; batch not supported)] ('Bradley Campbell', '2002-09-21', '93774', '9')
# 2025-04-13 17:49:46,143 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,144 INFO sqlalchemy.engine.Engine [insertmanyvalues 41/100 (ordered; batch not supported)] ('Anthony Murphy', '1972-03-30', '109892', '9')
# 17:49:46 INFO: [insertmanyvalues 41/100 (ordered; batch not supported)] ('Anthony Murphy', '1972-03-30', '109892', '9')
# 2025-04-13 17:49:46,144 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,144 INFO sqlalchemy.engine.Engine [insertmanyvalues 42/100 (ordered; batch not supported)] ('Brianna Torres', '1997-04-30', '107447', '7')
# 17:49:46 INFO: [insertmanyvalues 42/100 (ordered; batch not supported)] ('Brianna Torres', '1997-04-30', '107447', '7')
# 2025-04-13 17:49:46,145 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,145 INFO sqlalchemy.engine.Engine [insertmanyvalues 43/100 (ordered; batch not supported)] ('Thomas Powers', '1971-02-03', '90664', '8')
# 17:49:46 INFO: [insertmanyvalues 43/100 (ordered; batch not supported)] ('Thomas Powers', '1971-02-03', '90664', '8')
# 2025-04-13 17:49:46,145 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,146 INFO sqlalchemy.engine.Engine [insertmanyvalues 44/100 (ordered; batch not supported)] ('Cody Atkins', '1997-08-01', '116818', '3')
# 17:49:46 INFO: [insertmanyvalues 44/100 (ordered; batch not supported)] ('Cody Atkins', '1997-08-01', '116818', '3')
# 2025-04-13 17:49:46,146 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,146 INFO sqlalchemy.engine.Engine [insertmanyvalues 45/100 (ordered; batch not supported)] ('Melissa Ellis', '1970-05-31', '91117', '3')
# 17:49:46 INFO: [insertmanyvalues 45/100 (ordered; batch not supported)] ('Melissa Ellis', '1970-05-31', '91117', '3')
# 2025-04-13 17:49:46,147 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,147 INFO sqlalchemy.engine.Engine [insertmanyvalues 46/100 (ordered; batch not supported)] ('William Rubio', '1982-08-28', '102799', '7')
# 17:49:46 INFO: [insertmanyvalues 46/100 (ordered; batch not supported)] ('William Rubio', '1982-08-28', '102799', '7')
# 2025-04-13 17:49:46,147 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,148 INFO sqlalchemy.engine.Engine [insertmanyvalues 47/100 (ordered; batch not supported)] ('Dawn Dawson', '1987-09-22', '145393', '1')
# 17:49:46 INFO: [insertmanyvalues 47/100 (ordered; batch not supported)] ('Dawn Dawson', '1987-09-22', '145393', '1')
# 2025-04-13 17:49:46,148 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,149 INFO sqlalchemy.engine.Engine [insertmanyvalues 48/100 (ordered; batch not supported)] ('John Hicks', '1996-04-27', '77679', '3')
# 17:49:46 INFO: [insertmanyvalues 48/100 (ordered; batch not supported)] ('John Hicks', '1996-04-27', '77679', '3')
# 2025-04-13 17:49:46,149 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,149 INFO sqlalchemy.engine.Engine [insertmanyvalues 49/100 (ordered; batch not supported)] ('Kimberly Dixon', '1975-01-24', '89139', '1')
# 17:49:46 INFO: [insertmanyvalues 49/100 (ordered; batch not supported)] ('Kimberly Dixon', '1975-01-24', '89139', '1')
# 2025-04-13 17:49:46,150 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,150 INFO sqlalchemy.engine.Engine [insertmanyvalues 50/100 (ordered; batch not supported)] ('Jennifer Torres', '2003-06-27', '67204', '7')
# 17:49:46 INFO: [insertmanyvalues 50/100 (ordered; batch not supported)] ('Jennifer Torres', '2003-06-27', '67204', '7')
# 2025-04-13 17:49:46,151 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,151 INFO sqlalchemy.engine.Engine [insertmanyvalues 51/100 (ordered; batch not supported)] ('Emily Short', '1995-07-09', '48507', '8')
# 17:49:46 INFO: [insertmanyvalues 51/100 (ordered; batch not supported)] ('Emily Short', '1995-07-09', '48507', '8')
# 2025-04-13 17:49:46,151 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,152 INFO sqlalchemy.engine.Engine [insertmanyvalues 52/100 (ordered; batch not supported)] ('Ricky Scott MD', '1990-02-25', '87277', '7')
# 17:49:46 INFO: [insertmanyvalues 52/100 (ordered; batch not supported)] ('Ricky Scott MD', '1990-02-25', '87277', '7')
# 2025-04-13 17:49:46,152 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,152 INFO sqlalchemy.engine.Engine [insertmanyvalues 53/100 (ordered; batch not supported)] ('Johnny Barber', '1974-09-24', '148520', '4')
# 17:49:46 INFO: [insertmanyvalues 53/100 (ordered; batch not supported)] ('Johnny Barber', '1974-09-24', '148520', '4')
# 2025-04-13 17:49:46,153 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,153 INFO sqlalchemy.engine.Engine [insertmanyvalues 54/100 (ordered; batch not supported)] ('James Hernandez', '1973-01-05', '121415', '1')
# 17:49:46 INFO: [insertmanyvalues 54/100 (ordered; batch not supported)] ('James Hernandez', '1973-01-05', '121415', '1')
# 2025-04-13 17:49:46,154 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,154 INFO sqlalchemy.engine.Engine [insertmanyvalues 55/100 (ordered; batch not supported)] ('Julie Benjamin', '1973-09-25', '98074', '1')
# 17:49:46 INFO: [insertmanyvalues 55/100 (ordered; batch not supported)] ('Julie Benjamin', '1973-09-25', '98074', '1')
# 2025-04-13 17:49:46,154 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,155 INFO sqlalchemy.engine.Engine [insertmanyvalues 56/100 (ordered; batch not supported)] ('Nancy Murphy', '2005-06-29', '42742', '3')
# 17:49:46 INFO: [insertmanyvalues 56/100 (ordered; batch not supported)] ('Nancy Murphy', '2005-06-29', '42742', '3')
# 2025-04-13 17:49:46,155 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,156 INFO sqlalchemy.engine.Engine [insertmanyvalues 57/100 (ordered; batch not supported)] ('Taylor Estrada', '1986-08-10', '54914', '8')
# 17:49:46 INFO: [insertmanyvalues 57/100 (ordered; batch not supported)] ('Taylor Estrada', '1986-08-10', '54914', '8')
# 2025-04-13 17:49:46,156 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,157 INFO sqlalchemy.engine.Engine [insertmanyvalues 58/100 (ordered; batch not supported)] ('Leah Phelps', '1974-01-17', '62701', '5')
# 17:49:46 INFO: [insertmanyvalues 58/100 (ordered; batch not supported)] ('Leah Phelps', '1974-01-17', '62701', '5')
# 2025-04-13 17:49:46,157 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,157 INFO sqlalchemy.engine.Engine [insertmanyvalues 59/100 (ordered; batch not supported)] ('Angela Diaz', '1979-03-31', '88782', '3')
# 17:49:46 INFO: [insertmanyvalues 59/100 (ordered; batch not supported)] ('Angela Diaz', '1979-03-31', '88782', '3')
# 2025-04-13 17:49:46,158 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,158 INFO sqlalchemy.engine.Engine [insertmanyvalues 60/100 (ordered; batch not supported)] ('Daniel Brown', '1970-09-11', '102882', '5')
# 17:49:46 INFO: [insertmanyvalues 60/100 (ordered; batch not supported)] ('Daniel Brown', '1970-09-11', '102882', '5')
# 2025-04-13 17:49:46,159 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,159 INFO sqlalchemy.engine.Engine [insertmanyvalues 61/100 (ordered; batch not supported)] ('Rachel Turner', '1986-05-25', '50611', '8')
# 17:49:46 INFO: [insertmanyvalues 61/100 (ordered; batch not supported)] ('Rachel Turner', '1986-05-25', '50611', '8')
# 2025-04-13 17:49:46,159 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,160 INFO sqlalchemy.engine.Engine [insertmanyvalues 62/100 (ordered; batch not supported)] ('Rodney Mendoza', '1994-02-21', '50303', '2')
# 17:49:46 INFO: [insertmanyvalues 62/100 (ordered; batch not supported)] ('Rodney Mendoza', '1994-02-21', '50303', '2')
# 2025-04-13 17:49:46,160 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,160 INFO sqlalchemy.engine.Engine [insertmanyvalues 63/100 (ordered; batch not supported)] ('Chase Lee', '2001-11-09', '45160', '1')
# 17:49:46 INFO: [insertmanyvalues 63/100 (ordered; batch not supported)] ('Chase Lee', '2001-11-09', '45160', '1')
# 2025-04-13 17:49:46,161 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,161 INFO sqlalchemy.engine.Engine [insertmanyvalues 64/100 (ordered; batch not supported)] ('Christopher Dean', '2004-01-27', '79099', '5')
# 17:49:46 INFO: [insertmanyvalues 64/100 (ordered; batch not supported)] ('Christopher Dean', '2004-01-27', '79099', '5')
# 2025-04-13 17:49:46,162 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,162 INFO sqlalchemy.engine.Engine [insertmanyvalues 65/100 (ordered; batch not supported)] ('Marcus Mora', '1970-08-08', '108742', '8')
# 17:49:46 INFO: [insertmanyvalues 65/100 (ordered; batch not supported)] ('Marcus Mora', '1970-08-08', '108742', '8')
# 2025-04-13 17:49:46,162 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,163 INFO sqlalchemy.engine.Engine [insertmanyvalues 66/100 (ordered; batch not supported)] ('Stephen Jordan', '1999-10-11', '45006', '8')
# 17:49:46 INFO: [insertmanyvalues 66/100 (ordered; batch not supported)] ('Stephen Jordan', '1999-10-11', '45006', '8')
# 2025-04-13 17:49:46,163 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,163 INFO sqlalchemy.engine.Engine [insertmanyvalues 67/100 (ordered; batch not supported)] ('Donna Hicks', '2006-01-30', '136555', '5')
# 17:49:46 INFO: [insertmanyvalues 67/100 (ordered; batch not supported)] ('Donna Hicks', '2006-01-30', '136555', '5')
# 2025-04-13 17:49:46,164 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,164 INFO sqlalchemy.engine.Engine [insertmanyvalues 68/100 (ordered; batch not supported)] ('Douglas Blevins', '2004-06-24', '148235', '8')
# 17:49:46 INFO: [insertmanyvalues 68/100 (ordered; batch not supported)] ('Douglas Blevins', '2004-06-24', '148235', '8')
# 2025-04-13 17:49:46,165 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,165 INFO sqlalchemy.engine.Engine [insertmanyvalues 69/100 (ordered; batch not supported)] ('David Moore', '1983-06-10', '96900', '9')
# 17:49:46 INFO: [insertmanyvalues 69/100 (ordered; batch not supported)] ('David Moore', '1983-06-10', '96900', '9')
# 2025-04-13 17:49:46,166 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,166 INFO sqlalchemy.engine.Engine [insertmanyvalues 70/100 (ordered; batch not supported)] ('Kathryn Turner', '1972-08-20', '142079', '1')
# 17:49:46 INFO: [insertmanyvalues 70/100 (ordered; batch not supported)] ('Kathryn Turner', '1972-08-20', '142079', '1')
# 2025-04-13 17:49:46,166 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,167 INFO sqlalchemy.engine.Engine [insertmanyvalues 71/100 (ordered; batch not supported)] ('Madison Hawkins', '1969-09-22', '66148', '1')
# 17:49:46 INFO: [insertmanyvalues 71/100 (ordered; batch not supported)] ('Madison Hawkins', '1969-09-22', '66148', '1')
# 2025-04-13 17:49:46,167 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,167 INFO sqlalchemy.engine.Engine [insertmanyvalues 72/100 (ordered; batch not supported)] ('Wesley Jones', '1997-06-07', '70151', '1')
# 17:49:46 INFO: [insertmanyvalues 72/100 (ordered; batch not supported)] ('Wesley Jones', '1997-06-07', '70151', '1')
# 2025-04-13 17:49:46,168 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,168 INFO sqlalchemy.engine.Engine [insertmanyvalues 73/100 (ordered; batch not supported)] ('Natasha Stewart', '1999-04-13', '107155', '1')
# 17:49:46 INFO: [insertmanyvalues 73/100 (ordered; batch not supported)] ('Natasha Stewart', '1999-04-13', '107155', '1')
# 2025-04-13 17:49:46,169 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,169 INFO sqlalchemy.engine.Engine [insertmanyvalues 74/100 (ordered; batch not supported)] ('Joseph Cardenas', '1982-02-16', '140913', '4')
# 17:49:46 INFO: [insertmanyvalues 74/100 (ordered; batch not supported)] ('Joseph Cardenas', '1982-02-16', '140913', '4')
# 2025-04-13 17:49:46,170 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,170 INFO sqlalchemy.engine.Engine [insertmanyvalues 75/100 (ordered; batch not supported)] ('Ricky Cherry', '1975-09-21', '64551', '2')
# 17:49:46 INFO: [insertmanyvalues 75/100 (ordered; batch not supported)] ('Ricky Cherry', '1975-09-21', '64551', '2')
# 2025-04-13 17:49:46,171 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,171 INFO sqlalchemy.engine.Engine [insertmanyvalues 76/100 (ordered; batch not supported)] ('Ryan Smith', '2006-06-02', '59562', '6')
# 17:49:46 INFO: [insertmanyvalues 76/100 (ordered; batch not supported)] ('Ryan Smith', '2006-06-02', '59562', '6')
# 2025-04-13 17:49:46,172 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,172 INFO sqlalchemy.engine.Engine [insertmanyvalues 77/100 (ordered; batch not supported)] ('Eric Ramirez', '2005-01-07', '42342', '7')
# 17:49:46 INFO: [insertmanyvalues 77/100 (ordered; batch not supported)] ('Eric Ramirez', '2005-01-07', '42342', '7')
# 2025-04-13 17:49:46,173 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,173 INFO sqlalchemy.engine.Engine [insertmanyvalues 78/100 (ordered; batch not supported)] ('Chloe Davis', '2007-02-12', '36253', '8')
# 17:49:46 INFO: [insertmanyvalues 78/100 (ordered; batch not supported)] ('Chloe Davis', '2007-02-12', '36253', '8')
# 2025-04-13 17:49:46,173 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,174 INFO sqlalchemy.engine.Engine [insertmanyvalues 79/100 (ordered; batch not supported)] ('Alan Brown', '2003-11-11', '96444', '8')
# 17:49:46 INFO: [insertmanyvalues 79/100 (ordered; batch not supported)] ('Alan Brown', '2003-11-11', '96444', '8')
# 2025-04-13 17:49:46,174 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,175 INFO sqlalchemy.engine.Engine [insertmanyvalues 80/100 (ordered; batch not supported)] ('Amber Dunn', '2002-01-01', '47776', '3')
# 17:49:46 INFO: [insertmanyvalues 80/100 (ordered; batch not supported)] ('Amber Dunn', '2002-01-01', '47776', '3')
# 2025-04-13 17:49:46,175 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,176 INFO sqlalchemy.engine.Engine [insertmanyvalues 81/100 (ordered; batch not supported)] ('Jennifer Gonzalez', '1984-01-06', '102364', '8')
# 17:49:46 INFO: [insertmanyvalues 81/100 (ordered; batch not supported)] ('Jennifer Gonzalez', '1984-01-06', '102364', '8')
# 2025-04-13 17:49:46,176 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,177 INFO sqlalchemy.engine.Engine [insertmanyvalues 82/100 (ordered; batch not supported)] ('Emily Jones', '1973-03-16', '138448', '4')
# 17:49:46 INFO: [insertmanyvalues 82/100 (ordered; batch not supported)] ('Emily Jones', '1973-03-16', '138448', '4')
# 2025-04-13 17:49:46,177 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,178 INFO sqlalchemy.engine.Engine [insertmanyvalues 83/100 (ordered; batch not supported)] ('Julie Rivera', '2000-09-06', '74368', '6')
# 17:49:46 INFO: [insertmanyvalues 83/100 (ordered; batch not supported)] ('Julie Rivera', '2000-09-06', '74368', '6')
# 2025-04-13 17:49:46,178 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,179 INFO sqlalchemy.engine.Engine [insertmanyvalues 84/100 (ordered; batch not supported)] ('Mrs. Michele Miller', '1984-02-06', '67193', '2')
# 17:49:46 INFO: [insertmanyvalues 84/100 (ordered; batch not supported)] ('Mrs. Michele Miller', '1984-02-06', '67193', '2')
# 2025-04-13 17:49:46,180 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,180 INFO sqlalchemy.engine.Engine [insertmanyvalues 85/100 (ordered; batch not supported)] ('Marie Webb', '2005-10-18', '50785', '5')
# 17:49:46 INFO: [insertmanyvalues 85/100 (ordered; batch not supported)] ('Marie Webb', '2005-10-18', '50785', '5')
# 2025-04-13 17:49:46,181 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,181 INFO sqlalchemy.engine.Engine [insertmanyvalues 86/100 (ordered; batch not supported)] ('Courtney Ayers', '2001-04-27', '119340', '2')
# 17:49:46 INFO: [insertmanyvalues 86/100 (ordered; batch not supported)] ('Courtney Ayers', '2001-04-27', '119340', '2')
# 2025-04-13 17:49:46,182 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,182 INFO sqlalchemy.engine.Engine [insertmanyvalues 87/100 (ordered; batch not supported)] ('Miranda Campbell', '1975-07-30', '129160', '1')
# 17:49:46 INFO: [insertmanyvalues 87/100 (ordered; batch not supported)] ('Miranda Campbell', '1975-07-30', '129160', '1')
# 2025-04-13 17:49:46,183 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,183 INFO sqlalchemy.engine.Engine [insertmanyvalues 88/100 (ordered; batch not supported)] ('James Allen', '1997-01-03', '79430', '1')
# 17:49:46 INFO: [insertmanyvalues 88/100 (ordered; batch not supported)] ('James Allen', '1997-01-03', '79430', '1')
# 2025-04-13 17:49:46,184 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,184 INFO sqlalchemy.engine.Engine [insertmanyvalues 89/100 (ordered; batch not supported)] ('Lee Baldwin', '2003-08-21', '33792', '2')
# 17:49:46 INFO: [insertmanyvalues 89/100 (ordered; batch not supported)] ('Lee Baldwin', '2003-08-21', '33792', '2')
# 2025-04-13 17:49:46,184 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,185 INFO sqlalchemy.engine.Engine [insertmanyvalues 90/100 (ordered; batch not supported)] ('Chad Poole', '1986-07-11', '57716', '2')
# 17:49:46 INFO: [insertmanyvalues 90/100 (ordered; batch not supported)] ('Chad Poole', '1986-07-11', '57716', '2')
# 2025-04-13 17:49:46,185 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,186 INFO sqlalchemy.engine.Engine [insertmanyvalues 91/100 (ordered; batch not supported)] ('Jacqueline Cooper', '1994-12-11', '68868', '1')
# 17:49:46 INFO: [insertmanyvalues 91/100 (ordered; batch not supported)] ('Jacqueline Cooper', '1994-12-11', '68868', '1')
# 2025-04-13 17:49:46,186 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,187 INFO sqlalchemy.engine.Engine [insertmanyvalues 92/100 (ordered; batch not supported)] ('Lisa Jones', '1977-05-09', '31949', '6')
# 17:49:46 INFO: [insertmanyvalues 92/100 (ordered; batch not supported)] ('Lisa Jones', '1977-05-09', '31949', '6')
# 2025-04-13 17:49:46,187 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,188 INFO sqlalchemy.engine.Engine [insertmanyvalues 93/100 (ordered; batch not supported)] ('Shari Moss', '1970-07-07', '89191', '4')
# 17:49:46 INFO: [insertmanyvalues 93/100 (ordered; batch not supported)] ('Shari Moss', '1970-07-07', '89191', '4')
# 2025-04-13 17:49:46,188 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,189 INFO sqlalchemy.engine.Engine [insertmanyvalues 94/100 (ordered; batch not supported)] ('Austin Smith', '2000-06-28', '73350', '10')
# 17:49:46 INFO: [insertmanyvalues 94/100 (ordered; batch not supported)] ('Austin Smith', '2000-06-28', '73350', '10')
# 2025-04-13 17:49:46,189 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,190 INFO sqlalchemy.engine.Engine [insertmanyvalues 95/100 (ordered; batch not supported)] ('Barbara Smith', '1971-08-19', '70287', '4')
# 17:49:46 INFO: [insertmanyvalues 95/100 (ordered; batch not supported)] ('Barbara Smith', '1971-08-19', '70287', '4')
# 2025-04-13 17:49:46,190 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,190 INFO sqlalchemy.engine.Engine [insertmanyvalues 96/100 (ordered; batch not supported)] ('Robert Pollard', '1976-03-11', '55220', '5')
# 17:49:46 INFO: [insertmanyvalues 96/100 (ordered; batch not supported)] ('Robert Pollard', '1976-03-11', '55220', '5')
# 2025-04-13 17:49:46,191 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,191 INFO sqlalchemy.engine.Engine [insertmanyvalues 97/100 (ordered; batch not supported)] ('Jennifer Weber', '1994-11-26', '37089', '2')
# 17:49:46 INFO: [insertmanyvalues 97/100 (ordered; batch not supported)] ('Jennifer Weber', '1994-11-26', '37089', '2')
# 2025-04-13 17:49:46,192 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,193 INFO sqlalchemy.engine.Engine [insertmanyvalues 98/100 (ordered; batch not supported)] ('Teresa Vasquez', '1989-11-05', '89975', '4')
# 17:49:46 INFO: [insertmanyvalues 98/100 (ordered; batch not supported)] ('Teresa Vasquez', '1989-11-05', '89975', '4')
# 2025-04-13 17:49:46,193 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,193 INFO sqlalchemy.engine.Engine [insertmanyvalues 99/100 (ordered; batch not supported)] ('Paula White', '2003-03-24', '61869', '8')
# 17:49:46 INFO: [insertmanyvalues 99/100 (ordered; batch not supported)] ('Paula White', '2003-03-24', '61869', '8')
# 2025-04-13 17:49:46,194 INFO sqlalchemy.engine.Engine INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 17:49:46 INFO: INSERT INTO employees (name, date_of_birth, salary, department_id) VALUES (?, ?, ?, ?) RETURNING id
# 2025-04-13 17:49:46,194 INFO sqlalchemy.engine.Engine [insertmanyvalues 100/100 (ordered; batch not supported)] ('Frank Santana', '1979-09-27', '44572', '8')
# 17:49:46 INFO: [insertmanyvalues 100/100 (ordered; batch not supported)] ('Frank Santana', '1979-09-27', '44572', '8')
# 2025-04-13 17:49:46,196 INFO sqlalchemy.engine.Engine COMMIT
# 17:49:46 INFO: COMMIT
# 100 instances inserted successfully!

# %%
fake_departments = generate_departments(10)
insert_data(engine, fake_departments)
# Out:
# 2025-04-13 17:49:46,740 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 17:49:46 INFO: BEGIN (implicit)
# 2025-04-13 17:49:46,741 INFO sqlalchemy.engine.Engine INSERT INTO departments (id, name) VALUES (?, ?)
# 17:49:46 INFO: INSERT INTO departments (id, name) VALUES (?, ?)
# 2025-04-13 17:49:46,741 INFO sqlalchemy.engine.Engine [generated in 0.00067s] [(1, 'Human Resources'), (2, 'Engineering'), (3, 'Marketing'), (4, 'Sales'), (5, 'Finance'), (6, 'Operations'), (7, 'Legal'), (8, 'Customer Support'), (9, 'Product Management'), (10, 'IT')]
# 17:49:46 INFO: [generated in 0.00067s] [(1, 'Human Resources'), (2, 'Engineering'), (3, 'Marketing'), (4, 'Sales'), (5, 'Finance'), (6, 'Operations'), (7, 'Legal'), (8, 'Customer Support'), (9, 'Product Management'), (10, 'IT')]
# 2025-04-13 17:49:46,743 INFO sqlalchemy.engine.Engine COMMIT
# 17:49:46 INFO: COMMIT
# 10 instances inserted successfully!
